# %% [markdown]
# ##### Bombay hospitality Ltd. operates a franchise model for producing exotic Norwegian dinners throughout New England. The operating cost for a franchise in a week (W) is given by the equation W = $1,000 + $5X, where X represents the number of units produced in a week. Recent feedback from restaurant owners suggests that this cost model may no longer be accurate, as their observed weekly operating costs are higher.

# %% [markdown]
# ### Data Provided:
#     The theoretical weekly operating cost model: W = $1,000 + $5X
#     Sample of 25 restaurants with a mean weekly cost of Rs. 3,050
#     Number of units produced in a week (X) follows a normal distribution with a mean (μ) of 600 units and a standard deviation (σ) of 25 units

# %% [markdown]
# #### 1. State the Hypotheses statement:

# %% [markdown]
# ##### H0: The average weekly operating cost is W = $1,000 + $5X
# ##### H1: The average weekly operating cost is W > $1,000 + $5X

# %% [markdown]
# #### 2. Calculate the Test Statistic:

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
sample_mean = 3050
therotical_mean = 1000 + 5 * 600 # W=1000+5X where X=600 of weekly cost
sample_std = 5 * 25 # standard deviation of weekly cost
n = 25 # sample size

#calculating population standard deviation
pop_std = sample_std/np.sqrt(n)
print(pop_std)
# Out:
# 25.0

# %%
z_score= (sample_mean-therotical_mean)/pop_std
z_score
# Out:
# np.float64(-38.0)

# %% [markdown]
# #### 3. Determine the Critical Value:
#     Using the alpha level of 5% (α = 0.05), determine the critical value from the standard normal (Z) distribution table.

# %%
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha)
z_critical
# Out:
# np.float64(1.6448536269514722)

# %% [markdown]
# #### 4. Make a Decision:
#     Compare the test statistic with the critical value to decide whether to reject the null hypothesis.

# %%
if z_score > z_critical:
    print('conclusion: reject null hypothesis -> the actual weekly cost are higher than the model suggests')
else:
    print('conclusion: fail to reject null hypthesis -> the actual weekly cost are not higher than the model suggests')
# Out:
# conclusion: fail to reject null hypthesis -> the actual weekly cost are not higher than the model suggests
